# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import scipy.stats as sts
import numpy as np
import scipy.stats as st
from scipy import stats
from functools import reduce
output_data_file = "output_data/finaleonly.csv"

# %% [markdown]
# # Cleaning Data

# %%
resource1 = pd.read_csv('output_data/resourceprices1.csv')
resource2 = pd.read_csv('output_data/resourceprices2.csv')
clonly = pd.read_csv('output_data/clonly.csv')
ngonly = pd.read_csv('output_data/ngonly.csv')
paonly = pd.read_csv('output_data/paonly.csv')
sionly = pd.read_csv('output_data/sionly.csv')
STEELonly = pd.read_csv('output_data/STEELonly.csv')
Xonly = pd.read_csv('output_data/Xonly.csv')
GOLDonly = pd.read_csv('output_data/GOLDonly.csv')
allstocks = pd.read_csv('output_data/carstockprices.csv')
TSLA_only = pd.read_csv('output_data/TSLAonly.csv')
TM_only = pd.read_csv('output_data/TMonly.csv')
F_only = pd.read_csv('output_data/Fonly.csv')
GM_only = pd.read_csv('output_data/GMonly.csv')
HMC_only = pd.read_csv('output_data/HMConly.csv')
DDAIF_only = pd.read_csv('output_data/DDAIFonly.csv')
VWAGY_only = pd.read_csv('output_data/VWAGYonly.csv')
FUJHY_only = pd.read_csv('output_data/FUJHYonly.csv')
MZDAY_only = pd.read_csv('output_data/MZDAYonly.csv')
DODGX_only = pd.read_csv('output_data/DODGXonly.csv')

# %%
carsales = pd.read_csv('output_data/US_car_sales_20142021.csv')
carsales
# Out:
#          Date  Car sales
# 0   12/1/2013    1350623
# 1    1/1/2014    1006049
# 2    2/1/2014    1186038
# 3    3/1/2014    1529348
# 4    4/1/2014    1381300
# ..        ...        ...
# 86   2/1/2021    1256529
# 87   3/1/2021    1536038
# 88   4/1/2021    1493938
# 89   5/1/2021    1502642
# 90   6/1/2021    1352285
#
# [91 rows x 2 columns]

# %%
plt.plot(clonly['Date'], clonly['Close'])

# %%
plt.plot(clonly['Date'], carsales['Car sales'])

# %%
plt.plot(clonly['Date'], clonly['Close'])
plt.plot(clonly['Date'], carsales['Car sales'])
plt.show
CL_close = clonly.iloc[:,4]
Car_sales = carsales.iloc[:,1]
correlation = st.pearsonr(CL_close,Car_sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.04

# %%
plt.plot(ngonly['Date'], ngonly['Close'])
plt.plot(ngonly['Date'], carsales['Car sales'])
plt.show
NG_close = ngonly.iloc[:,4]
Car_sales = carsales.iloc[:,1]
correlation = st.pearsonr(NG_close,Car_sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.25

# %%
plt.plot(Xonly['Date'], Xonly['Close'])
plt.plot(Xonly['Date'], carsales['Car sales'])
plt.show
X_close = Xonly.iloc[:,4]
Car_sales = carsales.iloc[:,1]
correlation = st.pearsonr(X_close,Car_sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is 0.2

# %%
plt.plot(GOLDonly['Date'], GOLDonly['Close'])
plt.plot(GOLDonly['Date'], carsales['Car sales'])
plt.show
GOLD_close = GOLDonly.iloc[:,4]
Car_sales = carsales.iloc[:,1]
correlation = st.pearsonr(GOLD_close,Car_sales)
print(f"The correlation between both factors is {round(correlation[0],2)}")
# Out:
# The correlation between both factors is -0.26

# %%
#merging two of commodities together
merged_df = pd.merge(clonly, ngonly, on = "Date" )
merged_df
# Out:
#           Date     Open_x     High_x      Low_x    Close_x     Volume_x  \
# 0   2013-12-01  54.981842  55.275010  52.602981  54.621662   53782000.0
# 1   2014-01-01  54.353622  54.831069  50.257626  51.287907   75954700.0
# 2   2014-02-01  51.550264  53.175419  50.312450  52.905964   72438400.0
# 3   2014-03-01  52.400732  55.507893  52.207061  54.623745   64729700.0
# 4   2014-04-01  54.623753  57.217260  53.781700  56.669933   78204100.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  77.780614  79.254329  74.328755  74.378204   76863600.0
# 87  2021-03-01  74.615583  79.096078  73.329787  77.968536  126760600.0
# 88  2021-04-01  77.671816  81.153353  76.732200  79.818100   92791900.0
# 89  2021-05-01  80.406770  84.454966  79.760259  83.331017   74911000.0
# 90  2021-06-01  84.494746  84.554429  79.780150  80.914040   90945300.0
#
#    Ticker_x  Open_y  High_y  Low_y  Close_y  Volume_y Ticker_y
# ...

# %%
#only need the closing price so I am deleting the rest of the columns
del merged_df['Open_x']

del merged_df['High_x']

del merged_df['Low_x']

del merged_df['Volume_x']

del merged_df['Open_y']

del merged_df['High_y']

del merged_df['Low_y']

del merged_df['Volume_y']

merged_df
# Out:
#           Date    Close_x Ticker_x  Close_y Ticker_y
# 0   2013-12-01  54.621662       CL     2.54       NG
# 1   2014-01-01  51.287907       CL     2.91       NG
# 2   2014-02-01  52.905964       CL     3.69       NG
# 3   2014-03-01  54.623745       CL     3.61       NG
# 4   2014-04-01  56.669933       CL     3.53       NG
# ..         ...        ...      ...      ...      ...
# 86  2021-02-01  74.378204       CL     8.35       NG
# 87  2021-03-01  77.968536       CL     8.76       NG
# 88  2021-04-01  79.818100       CL     8.99       NG
# 89  2021-05-01  83.331017       CL    10.26       NG
# 90  2021-06-01  80.914040       CL     8.01       NG
#
# [91 rows x 5 columns]

# %%
#renaming the columns so I don't get confused
merged_df = merged_df.rename(columns={"Close_x":"CL Close","Ticker_x":"CL","Close_y":"NG Close","Ticker_y":"NG"})
merged_df
# Out:
#           Date   CL Close  CL  NG Close  NG
# 0   2013-12-01  54.621662  CL      2.54  NG
# 1   2014-01-01  51.287907  CL      2.91  NG
# 2   2014-02-01  52.905964  CL      3.69  NG
# 3   2014-03-01  54.623745  CL      3.61  NG
# 4   2014-04-01  56.669933  CL      3.53  NG
# ..         ...        ...  ..       ...  ..
# 86  2021-02-01  74.378204  CL      8.35  NG
# 87  2021-03-01  77.968536  CL      8.76  NG
# 88  2021-04-01  79.818100  CL      8.99  NG
# 89  2021-05-01  83.331017  CL     10.26  NG
# 90  2021-06-01  80.914040  CL      8.01  NG
#
# [91 rows x 5 columns]

# %%
#merging the last two commodities
merged_twoo_df = pd.merge(Xonly, GOLDonly, on = "Date" )
merged_twoo_df
# Out:
#           Date     Open_x     High_x      Low_x    Close_x     Volume_x  \
# 0   2013-12-01  25.039595  28.564450  24.177132  27.655113  128141200.0
# 1   2014-01-01  28.095722  29.201927  22.930308  24.477121  171994200.0
# 2   2014-02-01  24.514615  25.602071  21.861600  22.705315  142143500.0
# 3   2014-03-01  22.449194  26.431813  22.298907  25.933987  124179700.0
# 4   2014-04-01  26.084276  27.051750  23.811177  24.440506  109107400.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  18.042100  20.090069  16.114013  16.593538  412538900.0
# 87  2021-03-01  16.993451  27.389444  16.813520  26.159918  542431900.0
# 88  2021-04-01  25.630123  26.429816  20.652042  23.001137  416156600.0
# 89  2021-05-01  23.420975  29.958454  23.011133  25.920012  567561300.0
# 90  2021-06-01  26.400000  28.790001  22.500000  24.000000  564526400.0
#
#    Ticker_x     Open_y     High_y      Low_y    Close_y     Volume_y Ticker_y
# ...

# %%
#only need the closing price so I am deleting the rest of the columns
del merged_twoo_df['Open_x']

del merged_twoo_df['High_x']

del merged_twoo_df['Low_x']

del merged_twoo_df['Open_y']

del merged_twoo_df['High_y']

del merged_twoo_df['Low_y']

del merged_twoo_df['Volume_y']

merged_twoo_df
# Out:
#           Date    Close_x     Volume_x Ticker_x    Close_y Ticker_y
# 0   2013-12-01  27.655113  128141200.0        X  16.130062     GOLD
# 1   2014-01-01  24.477121  171994200.0        X  17.639677     GOLD
# 2   2014-02-01  22.705315  142143500.0        X  18.646093     GOLD
# 3   2014-03-01  25.933987  124179700.0        X  16.351828     GOLD
# 4   2014-04-01  24.440506  109107400.0        X  16.021667     GOLD
# ..         ...        ...          ...      ...        ...      ...
# 86  2021-02-01  16.593538  412538900.0        X  18.409718     GOLD
# 87  2021-03-01  26.159918  542431900.0        X  19.614727     GOLD
# 88  2021-04-01  23.001137  416156600.0        X  21.051159     GOLD
# 89  2021-05-01  25.920012  567561300.0        X  23.854679     GOLD
# 90  2021-06-01  24.000000  564526400.0        X  20.680000     GOLD
#
# [91 rows x 6 columns]

# %%
#renaming the columns so I don't get confused
merged_twoo_df = merged_twoo_df.rename(columns={"Close_x":"X Close","Ticker_x":"X","Close_y":"GOLD Close","Ticker_y":"GOLD"})
merged_twoo_df
# Out:
#           Date    X Close     Volume_x  X  GOLD Close  GOLD
# 0   2013-12-01  27.655113  128141200.0  X   16.130062  GOLD
# 1   2014-01-01  24.477121  171994200.0  X   17.639677  GOLD
# 2   2014-02-01  22.705315  142143500.0  X   18.646093  GOLD
# 3   2014-03-01  25.933987  124179700.0  X   16.351828  GOLD
# 4   2014-04-01  24.440506  109107400.0  X   16.021667  GOLD
# ..         ...        ...          ... ..         ...   ...
# 86  2021-02-01  16.593538  412538900.0  X   18.409718  GOLD
# 87  2021-03-01  26.159918  542431900.0  X   19.614727  GOLD
# 88  2021-04-01  23.001137  416156600.0  X   21.051159  GOLD
# 89  2021-05-01  25.920012  567561300.0  X   23.854679  GOLD
# 90  2021-06-01  24.000000  564526400.0  X   20.680000  GOLD
#
# [91 rows x 6 columns]

# %%
#merging all of the commodities together
final_merged_df = pd.merge(merged_df, merged_twoo_df, on = "Date" )
final_merged_df
# Out:
#           Date   CL Close  CL  NG Close  NG    X Close     Volume_x  X  \
# 0   2013-12-01  54.621662  CL      2.54  NG  27.655113  128141200.0  X
# 1   2014-01-01  51.287907  CL      2.91  NG  24.477121  171994200.0  X
# 2   2014-02-01  52.905964  CL      3.69  NG  22.705315  142143500.0  X
# 3   2014-03-01  54.623745  CL      3.61  NG  25.933987  124179700.0  X
# 4   2014-04-01  56.669933  CL      3.53  NG  24.440506  109107400.0  X
# ..         ...        ...  ..       ...  ..        ...          ... ..
# 86  2021-02-01  74.378204  CL      8.35  NG  16.593538  412538900.0  X
# 87  2021-03-01  77.968536  CL      8.76  NG  26.159918  542431900.0  X
# 88  2021-04-01  79.818100  CL      8.99  NG  23.001137  416156600.0  X
# 89  2021-05-01  83.331017  CL     10.26  NG  25.920012  567561300.0  X
# 90  2021-06-01  80.914040  CL      8.01  NG  24.000000  564526400.0  X
#
#     GOLD Close  GOLD
# 0    16.130062  GOLD
# 1    17.639677  GOLD
# 2    18.646093  GOLD
# 3    16.351828  GOLD
# ...

# %% [markdown]
# # Displaying Price of Stocks vs Price of Commodities

# %%
plt.plot(TSLA_only['Date'], TSLA_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
tsla_close = TSLA_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(tsla_close,cl_close)
correlation_two = st.pearsonr(tsla_close,ng_close)
correlation_three = st.pearsonr(tsla_close,x_close)
correlation_four = st.pearsonr(tsla_close,gold_close)
print(f"The correlation between tesla and oil is {round(correlation_one[0],2)}")
print(f"The correlation between tesla and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between tesla and steel is {round(correlation_three[0],2)}")
print(f"The correlation between tesla and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between tesla and oil is 0.79
# The correlation between tesla and natural gas is 0.71
# The correlation between tesla and steel is -0.18
# The correlation between tesla and gold is nan

# %%
plt.plot(TM_only['Date'], TM_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
TM_close = TM_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(TM_close,cl_close)
correlation_two = st.pearsonr(TM_close,ng_close)
correlation_three = st.pearsonr(TM_close,x_close)
correlation_four = st.pearsonr(TM_close,gold_close)
print(f"The correlation between Toyota Motors and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Toyota Motors and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Toyota Motors and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Toyota Motors and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Toyota Motors and oil is 0.67
# The correlation between Toyota Motors and natural gas is 0.54
# The correlation between Toyota Motors and steel is -0.06
# The correlation between Toyota Motors and gold is nan

# %%
plt.plot(F_only['Date'], F_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
F_close = TM_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(F_close,cl_close)
correlation_two = st.pearsonr(F_close,ng_close)
correlation_three = st.pearsonr(F_close,x_close)
correlation_four = st.pearsonr(F_close,gold_close)
print(f"The correlation between Ford and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Ford and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Ford and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Ford and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Ford and oil is 0.67
# The correlation between Ford and natural gas is 0.54
# The correlation between Ford and steel is -0.06
# The correlation between Ford and gold is nan

# %%
plt.plot(GM_only['Date'], GM_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
GM_close = GM_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(GM_close,cl_close)
correlation_two = st.pearsonr(GM_close,ng_close)
correlation_three = st.pearsonr(GM_close,x_close)
correlation_four = st.pearsonr(GM_close,gold_close)
print(f"The correlation between General Motors and oil is {round(correlation_one[0],2)}")
print(f"The correlation between General Motors and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between General Motors and steel is {round(correlation_three[0],2)}")
print(f"The correlation between General Motors and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between General Motors and oil is 0.64
# The correlation between General Motors and natural gas is 0.36
# The correlation between General Motors and steel is 0.16
# The correlation between General Motors and gold is nan

# %%
plt.plot(HMC_only['Date'], HMC_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
HMC_close = HMC_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(HMC_close,cl_close)
correlation_two = st.pearsonr(HMC_close,ng_close)
correlation_three = st.pearsonr(HMC_close,x_close)
correlation_four = st.pearsonr(HMC_close,gold_close)
print(f"The correlation between Honda Motor Co and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Honda Motor Co and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Honda Motor Co and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Honda Motor Co and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Honda Motor Co and oil is -0.49
# The correlation between Honda Motor Co and natural gas is -0.61
# The correlation between Honda Motor Co and steel is 0.63
# The correlation between Honda Motor Co and gold is nan

# %%
plt.plot(DDAIF_only['Date'], DDAIF_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
DDAIF_close = DDAIF_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(DDAIF_close,cl_close)
correlation_two = st.pearsonr(DDAIF_close,ng_close)
correlation_three = st.pearsonr(DDAIF_close,x_close)
correlation_four = st.pearsonr(DDAIF_close,gold_close)
print(f"The correlation between Daimler and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Daimler and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Daimler and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Daimler and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Daimler and oil is 0.09
# The correlation between Daimler and natural gas is -0.22
# The correlation between Daimler and steel is 0.49
# The correlation between Daimler and gold is nan

# %%
plt.plot(VWAGY_only['Date'], VWAGY_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
VWAGY_close = VWAGY_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(VWAGY_close,cl_close)
correlation_two = st.pearsonr(VWAGY_close,ng_close)
correlation_three = st.pearsonr(VWAGY_close,x_close)
correlation_four = st.pearsonr(VWAGY_close,gold_close)
print(f"The correlation between Volkswagen and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Volkswagen and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Volkswagen and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Volkswagen and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Volkswagen and oil is 0.17
# The correlation between Volkswagen and natural gas is 0.05
# The correlation between Volkswagen and steel is 0.31
# The correlation between Volkswagen and gold is nan

# %%
plt.plot(FUJHY_only['Date'], FUJHY_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
FUJHY_close = FUJHY_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(FUJHY_close,cl_close)
correlation_two = st.pearsonr(FUJHY_close,ng_close)
correlation_three = st.pearsonr(FUJHY_close,x_close)
correlation_four = st.pearsonr(FUJHY_close,gold_close)
print(f"The correlation between Subaru and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Subaru and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Subaru and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Subaru and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Subaru and oil is -0.56
# The correlation between Subaru and natural gas is -0.63
# The correlation between Subaru and steel is 0.31
# The correlation between Subaru and gold is nan

# %%
plt.plot(MZDAY_only['Date'], MZDAY_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
MZDAY_close = MZDAY_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(MZDAY_close,cl_close)
correlation_two = st.pearsonr(MZDAY_close,ng_close)
correlation_three = st.pearsonr(MZDAY_close,x_close)
correlation_four = st.pearsonr(MZDAY_close,gold_close)
print(f"The correlation between Mazda and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Mazda and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Mazda and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Mazda and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Mazda and oil is -0.76
# The correlation between Mazda and natural gas is -0.77
# The correlation between Mazda and steel is 0.42
# The correlation between Mazda and gold is nan

# %%
plt.plot(DODGX_only['Date'], DODGX_only['Close'])
plt.plot(final_merged_df['Date'], final_merged_df['CL Close'])
plt.plot(final_merged_df['Date'], final_merged_df['NG Close'])
plt.plot(final_merged_df['Date'], final_merged_df['X Close'])
plt.plot(final_merged_df['Date'], final_merged_df['GOLD Close'])
plt.show
DODGX_close = DODGX_only.iloc[:,4]
cl_close = final_merged_df.iloc[:,1]
ng_close = final_merged_df.iloc[:,3]
x_close = final_merged_df.iloc[:,5]
gold_close = final_merged_df.iloc[:,7]
correlation_one = st.pearsonr(DODGX_close,cl_close)
correlation_two = st.pearsonr(DODGX_close,ng_close)
correlation_three = st.pearsonr(DODGX_close,x_close)
correlation_four = st.pearsonr(DODGX_close,gold_close)
print(f"The correlation between Dodge and oil is {round(correlation_one[0],2)}")
print(f"The correlation between Dodge and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Dodge and steel is {round(correlation_three[0],2)}")
print(f"The correlation between Dodge and gold is {round(correlation_four[0],2)}")
# Out:
# C:\Users\harol\anaconda3\lib\site-packages\scipy\stats\stats.py:3913: PearsonRConstantInputWarning: An input array is constant; the correlation coefficent is not defined.
#   warnings.warn(PearsonRConstantInputWarning())
# The correlation between Dodge and oil is 0.56
# The correlation between Dodge and natural gas is 0.25
# The correlation between Dodge and steel is 0.34
# The correlation between Dodge and gold is nan

# %%
#realizing that comparing price of stocks to price of commodities is unfair since how much a stock moves is relative to the 
#how big the company is, I decided to calulate the percentage change of both the stocks and commodities

# %% [markdown]
# # Cleaning Up the Data To Fit Percentages For Stocks

# %%
TSLA_only['percent_change'] = TSLA_only['Close'].pct_change(1)
TSLA_only
# Out:
#           Date        Open        High         Low       Close        Volume  \
# 0   2013-12-01   25.270000   31.600000   24.785999   30.086000  9.881895e+08
# 1   2014-01-01   29.959999   37.200001   27.334000   36.282001  9.196615e+08
# 2   2014-02-01   36.577999   53.000000   33.872002   48.962002  1.129770e+09
# 3   2014-03-01   47.452000   52.000000   40.599998   41.689999  8.334280e+08
# 4   2014-04-01   41.804001   47.146000   36.863998   41.577999  8.260390e+08
# ..         ...         ...         ...         ...         ...           ...
# 86  2021-02-01  814.289978  880.500000  619.000000  675.500000  5.228579e+08
# 87  2021-03-01  690.109985  721.109985  539.489990  667.929993  9.424524e+08
# 88  2021-04-01  688.369995  780.789978  659.419983  709.440002  6.785397e+08
# 89  2021-05-01  703.799988  706.000000  546.979980  625.219971  6.251758e+08
# 90  2021-06-01  627.799988  697.619995  571.219971  679.700012  5.199219e+08
#
#    Ticker  percent_change
# ...

# %%
TSLA_only = TSLA_only.dropna()
TSLA_only
# Out:
#           Date        Open        High         Low       Close        Volume  \
# 1   2014-01-01   29.959999   37.200001   27.334000   36.282001  9.196615e+08
# 2   2014-02-01   36.577999   53.000000   33.872002   48.962002  1.129770e+09
# 3   2014-03-01   47.452000   52.000000   40.599998   41.689999  8.334280e+08
# 4   2014-04-01   41.804001   47.146000   36.863998   41.577999  8.260390e+08
# 5   2014-05-01   41.416000   43.731998   35.444000   41.554001  6.740505e+08
# ..         ...         ...         ...         ...         ...           ...
# 86  2021-02-01  814.289978  880.500000  619.000000  675.500000  5.228579e+08
# 87  2021-03-01  690.109985  721.109985  539.489990  667.929993  9.424524e+08
# 88  2021-04-01  688.369995  780.789978  659.419983  709.440002  6.785397e+08
# 89  2021-05-01  703.799988  706.000000  546.979980  625.219971  6.251758e+08
# 90  2021-06-01  627.799988  697.619995  571.219971  679.700012  5.199219e+08
#
#    Ticker  percent_change
# ...

# %%
TM_only['percent_change'] = TM_only['Close'].pct_change(1)
TM_only = TM_only.dropna()
TM_only
# Out:
#           Date        Open        High         Low       Close      Volume  \
# 1   2014-01-01  111.058872  111.186735  103.761502  104.811813   9045900.0
# 2   2014-02-01  104.090292  108.145405  101.149423  105.305000   7753200.0
# 3   2014-03-01  103.971562  105.286735   97.094315  103.113052   9660400.0
# 4   2014-04-01  105.053272  105.648527   96.152344  100.839981  11322900.0
# 5   2014-05-01  102.328116  105.462510  100.012203  105.202087   7703500.0
# ..         ...         ...         ...         ...         ...         ...
# 86  2021-02-01  140.160004  163.369995  139.289993  147.929993   8313600.0
# 87  2021-03-01  149.210007  159.550003  145.550003  156.059998   8918000.0
# 88  2021-04-01  153.600006  157.979996  149.899994  150.770004   5679300.0
# 89  2021-05-01  151.479996  166.779999  150.250000  165.979996   5591700.0
# 90  2021-06-01  171.470001  185.380005  171.029999  174.839996   7203400.0
#
#    Ticker  percent_change
# 1      TM       -0.058727
# ...

# %%
F_only['percent_change'] = F_only['Close'].pct_change(1)
F_only = F_only.dropna()
F_only
# Out:
#           Date       Open       High        Low      Close        Volume  \
# 1   2014-01-01  10.930932  11.895009  10.562314  10.604847  1.003488e+09
# 2   2014-02-01  10.718429  11.068564  10.289692  10.997108  7.126964e+08
# 3   2014-03-01  10.861347  11.311521  10.739871  11.147172  6.173546e+08
# 4   2014-04-01  11.197189  11.783130  11.097150  11.540178  6.641995e+08
# 5   2014-05-01  11.630363  11.925623  11.111858  11.839206  5.049235e+08
# ..         ...        ...        ...        ...        ...           ...
# 86  2021-02-01  10.650000  12.400000  10.360000  11.700000  1.454668e+09
# 87  2021-03-01  11.870000  13.620000  11.630000  12.250000  1.683493e+09
# 88  2021-04-01  12.280000  12.990000  11.140000  11.540000  1.329295e+09
# 89  2021-05-01  11.560000  15.050000  11.230000  14.530000  1.943955e+09
# 90  2021-06-01  14.720000  16.450001  14.440000  14.860000  1.924494e+09
#
#    Ticker  percent_change
# 1       F       -0.030460
# 2       F        0.036989
# ...

# %%
GM_only['percent_change'] = GM_only['Close'].pct_change(1)
GM_only = GM_only.dropna()
GM_only
# Out:
#           Date       Open       High        Low      Close       Volume  \
# 1   2014-01-01  31.441315  31.735016  27.731426  27.886005  540681600.0
# 2   2014-02-01  28.032854  28.697544  26.556628  27.978752  580146400.0
# 3   2014-03-01  27.592309  29.408608  25.946044  26.603003  510773700.0
# 4   2014-04-01  26.901580  27.837288  24.718264  26.885984  494224900.0
# 5   2014-05-01  27.034132  27.626748  25.700750  26.963957  264085600.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  51.459999  57.049999  49.349998  51.330002  419120700.0
# 87  2021-03-01  52.410000  62.240002  50.250000  57.459999  516563500.0
# 88  2021-04-01  57.919998  63.439999  54.709999  57.220001  343319800.0
# 89  2021-05-01  57.599998  60.720001  53.520000  59.310001  324490400.0
# 90  2021-06-01  59.990002  64.300003  58.410000  59.169998  356983500.0
#
#    Ticker  percent_change
# 1      GM       -0.117201
# 2      GM        0.003326
# ...

# %%
HMC_only['percent_change'] = HMC_only['Close'].pct_change(1)
HMC_only = HMC_only.dropna()
HMC_only
# Out:
#           Date       Open       High        Low      Close      Volume Ticker  \
# 1   2014-01-01  41.099998  41.380001  37.369999  37.509998   8304700.0    HMC
# 2   2014-02-01  37.160000  37.369999  35.419998  36.049999  11528900.0    HMC
# 3   2014-03-01  36.459999  37.400002  34.240002  35.340000  15640700.0    HMC
# 4   2014-04-01  35.270000  35.700001  32.419998  33.299999  24970900.0    HMC
# 5   2014-05-01  33.560001  35.230000  32.680000  35.180000  19037900.0    HMC
# ..         ...        ...        ...        ...        ...         ...    ...
# 86  2021-02-01  26.610001  29.990000  26.400000  27.670000  18544100.0    HMC
# 87  2021-03-01  28.299999  31.920000  28.190001  30.200001  21133900.0    HMC
# 88  2021-04-01  30.139999  30.920000  29.139999  29.820000  19911700.0    HMC
# 89  2021-05-01  30.020000  31.530001  29.459999  31.260000  21143700.0    HMC
# 90  2021-06-01  30.900000  33.320000  30.900000  32.180000  16281600.0    HMC
#
#     percent_change
# ...

# %%
DDAIF_only['percent_change'] = DDAIF_only['Close'].pct_change(1)
DDAIF_only = DDAIF_only.dropna()
DDAIF_only
# Out:
#           Date       Open       High        Low      Close    Volume Ticker  \
# 1   2014-01-01  61.890101  65.279653  59.879600  60.677994  826400.0  DDAIF
# 2   2014-02-01  60.046528  67.638533  58.558608  67.065140  842100.0  DDAIF
# 3   2014-03-01  65.519157  69.540163  63.871563  68.785316  906100.0  DDAIF
# 4   2014-04-01  69.953879  71.093406  62.942526  67.326439  986700.0  DDAIF
# 5   2014-05-01  69.299451  71.525970  66.165832  71.331055  529600.0  DDAIF
# ..         ...        ...        ...        ...        ...       ...    ...
# 86  2021-02-01  69.291422  80.548576  69.094958  78.878670  589000.0  DDAIF
# 87  2021-03-01  78.308933  88.230159  77.984773  87.905998  618800.0  DDAIF
# 88  2021-04-01  86.776349  91.766433  85.165378  87.051399  545000.0  DDAIF
# 89  2021-05-01  90.250000  95.599998  83.800003  93.400002  541200.0  DDAIF
# 90  2021-06-01  94.889999  98.000000  89.010002  89.900002  783500.0  DDAIF
#
#     percent_change
# 1        -0.038196
# ...

# %%
VWAGY_only['percent_change'] = VWAGY_only['Close'].pct_change(1)
VWAGY_only = VWAGY_only.dropna()
VWAGY_only
# Out:
#           Date       Open       High        Low      Close      Volume Ticker  \
# 1   2014-01-01  25.245627  25.645068  22.839469  23.029680   2723600.0  VWAGY
# 2   2014-02-01  23.137624  25.635557  22.516112  24.232758   2225200.0  VWAGY
# 3   2014-03-01  23.581289  24.223247  22.516112  24.147163   2870800.0  VWAGY
# 4   2014-04-01  24.371137  25.607026  24.066326  25.421572   2671000.0  VWAGY
# 5   2014-05-01  25.377349  25.377349  23.785766  24.974579   1632200.0  VWAGY
# ..         ...        ...        ...        ...        ...         ...    ...
# 86  2021-02-01  20.643040  23.420266  20.565430  23.005695   6550300.0  VWAGY
# 87  2021-03-01  22.909422  47.862225  22.870127  35.660892  66224800.0  VWAGY
# 88  2021-04-01  35.729659  36.741528  31.063291  31.151705  17858300.0  VWAGY
# 89  2021-05-01  31.807943  35.955610  29.918801  35.528271  10764200.0  VWAGY
# 90  2021-06-01  35.659908  37.674796  32.124274  32.301105   8780600.0  VWAGY
#
#     percent_change
# ...

# %%
FUJHY_only['percent_change'] = FUJHY_only['Close'].pct_change(1)
FUJHY_only = FUJHY_only.dropna()
FUJHY_only
# Out:
#           Date     Open     High      Low    Close     Volume Ticker  \
# 1   2014-01-01  14.3800  14.7050  13.6075  13.7075   568400.0  FUJHY
# 2   2014-02-01  13.4950  13.8650  12.2875  13.4275   833600.0  FUJHY
# 3   2014-03-01  13.4175  13.7375  12.5250  13.6000  1270800.0  FUJHY
# 4   2014-04-01  13.6250  14.1750  12.9450  13.1000   638800.0  FUJHY
# 5   2014-05-01  13.4075  13.4075  11.8100  13.3250  1626800.0  FUJHY
# ..         ...      ...      ...      ...      ...        ...    ...
# 86  2021-02-01   9.9300  10.5000   9.1500   9.4400  1111200.0  FUJHY
# 87  2021-03-01   9.5400  10.4000   9.1800  10.0000  1288200.0  FUJHY
# 88  2021-04-01   9.7600  10.2200   9.1700   9.2800  1264400.0  FUJHY
# 89  2021-05-01   9.2500   9.9500   8.9500   9.8100  3412000.0  FUJHY
# 90  2021-06-01   9.8200  10.5000   9.7500   9.8900  1516900.0  FUJHY
#
#     percent_change
# 1        -0.046766
# 2        -0.020427
# 3         0.012847
# 4        -0.036765
# 5         0.017176
# ...

# %%
MZDAY_only['percent_change'] = MZDAY_only['Close'].pct_change(1)
MZDAY_only = MZDAY_only.dropna()
MZDAY_only
# Out:
#           Date     Open     High      Low    Close     Volume Ticker  \
# 1   2014-01-01  12.9500  13.5750  12.0300  12.0325   292000.0  MZDAY
# 2   2014-02-01  11.6850  12.5375  11.1750  12.0300   233200.0  MZDAY
# 3   2014-03-01  11.6100  11.9750  10.3250  11.1250   139600.0  MZDAY
# 4   2014-04-01  11.3250  11.5750  10.6725  11.3050   123600.0  MZDAY
# 5   2014-05-01  11.3125  11.5100  10.1625  10.9000    82000.0  MZDAY
# ..         ...      ...      ...      ...      ...        ...    ...
# 86  2021-02-01   3.7100   4.5700   3.5700   3.9700  1159600.0  MZDAY
# 87  2021-03-01   4.0800   4.3700   3.8800   4.0900  1040600.0  MZDAY
# 88  2021-04-01   4.0500   4.2000   3.7600   3.8500  1119900.0  MZDAY
# 89  2021-05-01   3.9300   4.3900   3.7400   4.3500  1355700.0  MZDAY
# 90  2021-06-01   4.3600   4.9000   4.2300   4.6600  1249000.0  MZDAY
#
#     percent_change
# 1        -0.077969
# 2        -0.000208
# 3        -0.075229
# 4         0.016180
# 5        -0.035825
# ...

# %%
DODGX_only['percent_change'] = DODGX_only['Close'].pct_change(1)
DODGX_only = DODGX_only.dropna()
DODGX_only
# Out:
#           Date        Open        High         Low       Close  Volume Ticker  \
# 1   2014-01-01  147.764720  149.266661  143.744811  144.292587     0.0  DODGX
# 2   2014-02-01  141.103108  150.795044  141.103108  150.795044     0.0  DODGX
# 3   2014-03-01  149.169413  152.570877  148.453783  151.793396     0.0  DODGX
# 4   2014-04-01  153.768185  154.426345  147.649115  152.016068     0.0  DODGX
# 5   2014-05-01  152.122818  155.120102  150.575272  155.120102     0.0  DODGX
# ..         ...         ...         ...         ...         ...     ...    ...
# 86  2021-02-01  193.310544  215.504983  193.310544  209.433853     0.0  DODGX
# 87  2021-03-01  214.350481  225.537279  213.643851  219.714966     0.0  DODGX
# 88  2021-04-01  223.309998  235.720001  223.309998  232.839996     0.0  DODGX
# 89  2021-05-01  235.130005  241.830002  233.289993  240.740005     0.0  DODGX
# 90  2021-06-01  243.000000  244.679993  233.320007  239.559998     0.0  DODGX
#
#     percent_change
# ...

# %%
#merging the data
final_stock_merge = [TSLA_only, TM_only, F_only, GM_only, HMC_only, DDAIF_only, VWAGY_only, FUJHY_only, MZDAY_only, DODGX_only]
finale_stock_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Date'],
                                            how='outer'), final_stock_merge)
finale_stock_merged
# Out:
#           Date      Open_x      High_x       Low_x     Close_x      Volume_x  \
# 0   2014-01-01   29.959999   37.200001   27.334000   36.282001  9.196615e+08
# 1   2014-02-01   36.577999   53.000000   33.872002   48.962002  1.129770e+09
# 2   2014-03-01   47.452000   52.000000   40.599998   41.689999  8.334280e+08
# 3   2014-04-01   41.804001   47.146000   36.863998   41.577999  8.260390e+08
# 4   2014-05-01   41.416000   43.731998   35.444000   41.554001  6.740505e+08
# ..         ...         ...         ...         ...         ...           ...
# 85  2021-02-01  814.289978  880.500000  619.000000  675.500000  5.228579e+08
# 86  2021-03-01  690.109985  721.109985  539.489990  667.929993  9.424524e+08
# 87  2021-04-01  688.369995  780.789978  659.419983  709.440002  6.785397e+08
# 88  2021-05-01  703.799988  706.000000  546.979980  625.219971  6.251758e+08
# 89  2021-06-01  627.799988  697.619995  571.219971  679.700012  5.199219e+08
#
# ...

# %%
finale_stock_merged.to_csv(output_data_file, encoding= "utf-8", index = True, header= True)

# %%
#calculating the average percent change of all of the stocks
finale_stock_merged['average_percentage'] = finale_stock_merged[['percent_change_x', 'percent_change_y', 'percent_change_x', 'percent_change_y','percent_change_x', 'percent_change_y', 'percent_change_x', 'percent_change_y', 'percent_change_x', 'percent_change_y']].mean(axis=1)
finale_stock_merged
# Out:
#           Date      Open_x      High_x       Low_x     Close_x      Volume_x  \
# 0   2014-01-01   29.959999   37.200001   27.334000   36.282001  9.196615e+08
# 1   2014-02-01   36.577999   53.000000   33.872002   48.962002  1.129770e+09
# 2   2014-03-01   47.452000   52.000000   40.599998   41.689999  8.334280e+08
# 3   2014-04-01   41.804001   47.146000   36.863998   41.577999  8.260390e+08
# 4   2014-05-01   41.416000   43.731998   35.444000   41.554001  6.740505e+08
# ..         ...         ...         ...         ...         ...           ...
# 85  2021-02-01  814.289978  880.500000  619.000000  675.500000  5.228579e+08
# 86  2021-03-01  690.109985  721.109985  539.489990  667.929993  9.424524e+08
# 87  2021-04-01  688.369995  780.789978  659.419983  709.440002  6.785397e+08
# 88  2021-05-01  703.799988  706.000000  546.979980  625.219971  6.251758e+08
# 89  2021-06-01  627.799988  697.619995  571.219971  679.700012  5.199219e+08
#
# ...

# %%
finale_stock_merged['average_percentage'].plot(figsize=(12, 8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Cleaning Up the Data To Fit Percentages For Stocks

# %%
clonly['percent_change'] = clonly['Close'].pct_change(1)
clonly = clonly.dropna()
clonly
# Out:
#           Date       Open       High        Low      Close       Volume  \
# 1   2014-01-01  54.353622  54.831069  50.257626  51.287907   75954700.0
# 2   2014-02-01  51.550264  53.175419  50.312450  52.905964   72438400.0
# 3   2014-03-01  52.400732  55.507893  52.207061  54.623745   64729700.0
# 4   2014-04-01  54.623753  57.217260  53.781700  56.669933   78204100.0
# 5   2014-05-01  56.873647  57.965743  55.959332  57.906483   58331300.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  77.780614  79.254329  74.328755  74.378204   76863600.0
# 87  2021-03-01  74.615583  79.096078  73.329787  77.968536  126760600.0
# 88  2021-04-01  77.671816  81.153353  76.732200  79.818100   92791900.0
# 89  2021-05-01  80.406770  84.454966  79.760259  83.331017   74911000.0
# 90  2021-06-01  84.494746  84.554429  79.780150  80.914040   90945300.0
#
#    Ticker  percent_change
# 1      CL       -0.061034
# 2      CL        0.031549
# ...

# %%
ngonly['percent_change'] = ngonly['Close'].pct_change(1)
ngonly = ngonly.dropna()
ngonly
# Out:
#           Date   Open   High   Low  Close    Volume Ticker  percent_change
# 1   2014-01-01   2.63   3.21  2.54   2.91  39781200     NG        0.145669
# 2   2014-02-01   2.95   3.80  2.91   3.69  49578900     NG        0.268041
# 3   2014-03-01   3.84   4.62  3.41   3.61  75878900     NG       -0.021680
# 4   2014-04-01   3.65   3.88  3.35   3.53  26928400     NG       -0.022161
# 5   2014-05-01   3.49   3.67  2.91   3.01  27720500     NG       -0.147309
# ..         ...    ...    ...   ...    ...       ...    ...             ...
# 86  2021-02-01   9.48   9.85  8.31   8.35  23864500     NG       -0.084430
# 87  2021-03-01   8.36   9.67  8.01   8.76  31688700     NG        0.049102
# 88  2021-04-01   8.86   9.94  8.81   8.99  16787600     NG        0.026256
# 89  2021-05-01   9.08  10.39  9.06  10.26  15419300     NG        0.141268
# 90  2021-06-01  10.39  10.45  7.85   8.01  26262000     NG       -0.219298
#
# [90 rows x 8 columns]

# %%
Xonly['percent_change'] = Xonly['Close'].pct_change(1)
Xonly = Xonly.dropna()
Xonly
# Out:
#           Date       Open       High        Low      Close       Volume  \
# 1   2014-01-01  28.095722  29.201927  22.930308  24.477121  171994200.0
# 2   2014-02-01  24.514615  25.602071  21.861600  22.705315  142143500.0
# 3   2014-03-01  22.449194  26.431813  22.298907  25.933987  124179700.0
# 4   2014-04-01  26.084276  27.051750  23.811177  24.440506  109107400.0
# 5   2014-05-01  24.431108  24.910150  21.538074  21.641397  104778700.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  18.042100  20.090069  16.114013  16.593538  412538900.0
# 87  2021-03-01  16.993451  27.389444  16.813520  26.159918  542431900.0
# 88  2021-04-01  25.630123  26.429816  20.652042  23.001137  416156600.0
# 89  2021-05-01  23.420975  29.958454  23.011133  25.920012  567561300.0
# 90  2021-06-01  26.400000  28.790001  22.500000  24.000000  564526400.0
#
#    Ticker  percent_change
# 1       X       -0.114915
# 2       X       -0.072386
# ...

# %%
GOLDonly['percent_change'] = GOLDonly['Close'].pct_change(1)
GOLDonly = GOLDonly.dropna()
GOLDonly
# Out:
#           Date       Open       High        Low      Close       Volume  \
# 1   2014-01-01  16.431980  18.252674  16.084311  17.639677  304438500.0
# 2   2014-02-01  17.822665  19.625061  16.779655  18.646093  273431000.0
# 3   2014-03-01  19.203998  19.350733  16.250946  16.351828  241822800.0
# 4   2014-04-01  16.443533  17.626586  15.746539  16.021667  241636600.0
# 5   2014-05-01  15.847426  16.186751  14.187482  14.774424  183447200.0
# ..         ...        ...        ...        ...        ...          ...
# 86  2021-02-01  22.610328  22.649770  18.380135  18.409718  399603000.0
# 87  2021-03-01  18.822214  21.140318  18.624084  19.614727  421570400.0
# 88  2021-04-01  19.911920  22.646094  19.753417  21.051159  338631300.0
# 89  2021-05-01  21.378072  25.132609  21.318634  23.854679  361623400.0
# 90  2021-06-01  24.129999  24.370001  20.290001  20.680000  326764400.0
#
#    Ticker  percent_change
# 1    GOLD        0.093590
# 2    GOLD        0.057054
# ...

# %% [markdown]
# # Displaying the Graphs Needed for the Presentation

# %%
#Graphing the average percent change of all stocks vs the percent change of the individual commodities
month = finale_stock_merged.iloc[:,0]
average_percent = finale_stock_merged.iloc[:,70]
average_percent_c = clonly.iloc[:,7]
average_percent_ng = ngonly.iloc[:,7]
average_percent_x = Xonly.iloc[:,7]
average_percent_gold = GOLDonly.iloc[:,7]

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, sharex=True)
fig.suptitle("Average Percentage of All Stocks Vs. Percentage of Commodities", fontsize=16, fontweight="bold")

ax1.set_xticklabels([])
ax1.plot(month, average_percent, linewidth=1)
ax1.set_ylabel("All Stocks")

ax2.set_xticklabels([])
ax2.plot(month, average_percent_c, linewidth=1, color="r")
ax2.set_ylabel("Oil")

ax3.set_xticklabels([])
ax3.plot(month, average_percent_ng, linewidth=1, color="g")
ax3.set_ylabel("NG")

ax4.set_xticklabels([])
ax4.plot(month, average_percent_x, linewidth=1, color="purple")
ax4.set_ylabel("Steel")

ax5.set_xticklabels([])
ax5.plot(month, average_percent_gold, linewidth=1, color="orange")
ax5.set_ylabel("Gold")
ax5.set_xlabel("Monthly From 2014 to 2021")

correlation_one = st.pearsonr(average_percent,average_percent_c)
correlation_two = st.pearsonr(average_percent,average_percent_ng)
correlation_three = st.pearsonr(average_percent,average_percent_x)
correlation_four = st.pearsonr(average_percent,average_percent_gold)
print(f"The correlation between the total average percent of all stocks and oil is {round(correlation_one[0],2)}")
print(f"The correlation between the total average percent of all stocks and natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between the total average percent of all stocks and steel is {round(correlation_three[0],2)}")
print(f"The correlation between the total average percent of all stocks and gold is {round(correlation_four[0],2)}")

plt.savefig("output_data/Commodity_visuals/Commodity Impact on Auto Stocks.png")

plt.show()
# Out:
# The correlation between the total average percent of all stocks and oil is 0.39
# The correlation between the total average percent of all stocks and natural gas is 0.07
# The correlation between the total average percent of all stocks and steel is 0.48
# The correlation between the total average percent of all stocks and gold is -0.03

# %%
#graphing the correlation coefficient for a better visual
y_values = [0.39, 0.07, 0.48, -0.03] 
x_axis = ['Oil', 'Natural Gas', 'Steel', 'Gold']
plt.bar(x_axis, y_values, color='blue')
plt.xticks(x_axis)  
plt.title('Commodity Impact on Auto Stocks')
plt.xlabel('Commodities')
plt.ylabel('Correlation Coefficient')
plt.grid(linestyle='-', color='black', alpha=0.75)

plt.savefig("output_data/Commodity_visuals/Commodity Impact on Auto Stocks Coefficient.png")

# %%
#making sure the amount of rows matches up with the rest of the data
carsales = carsales.drop(0)

# %%
#Graphing the car sales vs the price of the individual commodities
month = finale_stock_merged.iloc[:,0]
carsalesss = carsales.iloc[:,1]
cl_price = clonly.iloc[:,4]
ng_price = ngonly.iloc[:,4]
X_price = Xonly.iloc[:,4]
GOLD_price = GOLDonly.iloc[:,4]

fig, (ax1, ax2, ax3, ax4, ax5) = plt.subplots(5, sharex=True)
fig.suptitle("Car Sales Vs. Price of Commodities", fontsize=16, fontweight="bold")

ax1.set_xticklabels([])
ax1.plot(month, carsalesss, linewidth=1)
ax1.set_ylabel("Car Sales")

ax2.set_xticklabels([])
ax2.plot(month, cl_price, linewidth=1, color="r")
ax2.set_ylabel("Oil")

ax3.set_xticklabels([])
ax3.plot(month, ng_price, linewidth=1, color="g")
ax3.set_ylabel("NG")

ax4.set_xticklabels([])
ax4.plot(month, X_price, linewidth=1, color="purple")
ax4.set_ylabel("Steel")

ax5.set_xticklabels([])
ax5.plot(month, GOLD_price, linewidth=1, color="orange")
ax5.set_ylabel("Gold")
ax5.set_xlabel("Monthly From 2014 to 2021")

correlation_one = st.pearsonr(carsalesss,cl_price)
correlation_two = st.pearsonr(carsalesss,ng_price)
correlation_three = st.pearsonr(carsalesss,X_price)
correlation_four = st.pearsonr(carsalesss,GOLD_price)
print(f"The correlation between Car Sales and the price of oil is {round(correlation_one[0],2)}")
print(f"The correlation between Car Sales and the price of natural gas is {round(correlation_two[0],2)}")
print(f"The correlation between Car Sales and the price of steel is {round(correlation_three[0],2)}")
print(f"The correlation between Car Sales and the price of gold is {round(correlation_four[0],2)}")

plt.savefig("output_data/Commodity_visuals/Commodity Price Impact on Car Sales.png")

plt.show()
# Out:
# The correlation between Car Sales and the price of oil is -0.05
# The correlation between Car Sales and the price of natural gas is -0.26
# The correlation between Car Sales and the price of steel is 0.2
# The correlation between Car Sales and the price of gold is -0.26

# %%
#graphing the correlation coefficient for a better visual
y_values = [-.05, -.26, .2, -0.26] 
x_axis = ['Oil', 'Natural Gas', 'Steel', 'Gold']
plt.bar(x_axis, y_values, color='blue')
plt.xticks(x_axis)  
plt.title('Commodity Price Impact on Car Sales')
plt.xlabel('Commodities')
plt.ylabel('Correlation Coefficient')
plt.grid(linestyle='-', color='black', alpha=0.75)

plt.savefig("output_data/Commodity_visuals/Commodity Price Impact on Car Sales Coefficient.png")

# %%
#graphing the price of commodities all together
fig, ax = plt.subplots()
ax.plot(final_merged_df['Date'], final_merged_df['CL Close'], 'k', label='Crude Oil', color='blue')
ax.plot(final_merged_df['Date'], final_merged_df['NG Close'], 'k', label='Natural Gas', color='red')
ax.plot(final_merged_df['Date'], final_merged_df['X Close'], 'k', label='Steel', color='purple' )
ax.plot(final_merged_df['Date'], final_merged_df['GOLD Close'], 'k', label='Gold', color='green')
ax.set_xticklabels([])
ax.set_ylabel("Price")
ax.set_xlabel("Monthly From 2014 to 2021")
fig.suptitle("Commodities", fontsize=16, fontweight="bold")
plt.savefig("output_data/Commodity_visuals/commodity.png")

legend = ax.legend(loc='best', shadow=True, fontsize='medium')
